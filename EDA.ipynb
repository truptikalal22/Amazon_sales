# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("Amazon_sales_cleaned.csv")

# %%
print(df.shape)
# Out:
# (121019, 18)

# %%
display(df.head())
# Out:
#               Order ID        Date                        Status Fulfilment  \
# 0  405-8078784-5731545  2022-04-30                     Cancelled   Merchant
# 1  171-9198151-1101146  2022-04-30  Shipped - Delivered to Buyer   Merchant
# 2  404-0687676-7273146  2022-04-30                       Shipped     Amazon
# 3  403-9615377-8133951  2022-04-30                     Cancelled   Merchant
# 4  407-1069790-7240320  2022-04-30                       Shipped     Amazon
#
#   Sales Channel ship-service-level  Category Size Courier Status  Qty  \
# 0     Amazon.in           Standard   T-shirt    S     On the Way    0
# 1     Amazon.in           Standard     Shirt  3XL        Shipped    1
# 2     Amazon.in          Expedited     Shirt   XL        Shipped    1
# 3     Amazon.in           Standard   Blazzer    L     On the Way    0
# 4     Amazon.in          Expedited  Trousers  3XL        Shipped    1
#
#   currency  Amount    ship-city   ship-state  ship-postal-code ship-country  \
# 0      INR  647.62       MUMBAI  MAHARASHTRA          400081.0           IN
# 1      INR  406.00    BENGALURU    KARNATAKA          560085.0           IN
# 2      INR  329.00  NAVI MUMBAI  MAHARASHTRA          410210.0           IN
# 3      INR  753.33   PUDUCHERRY   PUDUCHERRY          605008.0           IN
# 4      INR  574.00      CHENNAI   TAMIL NADU          600073.0           IN
#
#      B2B fulfilled-by
# 0  False    Easy Ship
# 1  False    Easy Ship
# 2   True       unkown
# 3  False    Easy Ship
# 4  False       unkown

# %%
display(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 121019 entries, 0 to 121018
# Data columns (total 18 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   Order ID            121019 non-null  object
#  1   Date                121019 non-null  object
#  2   Status              121019 non-null  object
#  3   Fulfilment          121019 non-null  object
#  4   Sales Channel       121019 non-null  object
#  5   ship-service-level  121019 non-null  object
#  6   Category            121019 non-null  object
#  7   Size                121019 non-null  object
#  8   Courier Status      121019 non-null  object
#  9   Qty                 121019 non-null  int64
#  10  currency            121019 non-null  object
#  11  Amount              121019 non-null  float64
#  12  ship-city           121019 non-null  object
#  13  ship-state          121019 non-null  object
#  14  ship-postal-code    121019 non-null  float64
#  15  ship-country        120988 non-null  object
#  16  B2B                 121019 non-null  bool
#  17  fulfilled-by        121019 non-null  object
# dtypes: bool(1), float64(2), int64(1), object(14)
# memory usage: 15.8+ MB
# None

# %%
display(df.describe(include="all"))
# Out:
#                    Order ID        Date   Status Fulfilment Sales Channel  \
# count                121019      121019   121019     121019        121019
# unique               112887          91       12          2             1
# top     403-4984515-8861958  2022-05-02  Shipped     Amazon     Amazon.in
# freq                     12        1932    77505      83542        121019
# mean                    NaN         NaN      NaN        NaN           NaN
# std                     NaN         NaN      NaN        NaN           NaN
# min                     NaN         NaN      NaN        NaN           NaN
# 25%                     NaN         NaN      NaN        NaN           NaN
# 50%                     NaN         NaN      NaN        NaN           NaN
# 75%                     NaN         NaN      NaN        NaN           NaN
# max                     NaN         NaN      NaN        NaN           NaN
#
#        ship-service-level Category    Size Courier Status            Qty  \
# count              121019   121019  121019         121019  121019.000000
# unique                  2        9      11              3            NaN
# top             Expedited  T-shirt       M        Shipped            NaN
# freq                82627    46980   20948         109341            NaN
# mean                  NaN      NaN     NaN            NaN       0.961246
# std                   NaN      NaN     NaN            NaN       0.214311
# min                   NaN      NaN     NaN            NaN       0.000000
# 25%                   NaN      NaN     NaN            NaN       1.000000
# 50%                   NaN      NaN     NaN            NaN       1.000000
# 75%                   NaN      NaN     NaN            NaN       1.000000
# max                   NaN      NaN     NaN            NaN       8.000000
#
#        currency         Amount  ship-city   ship-state  ship-postal-code  \
# count    121019  121019.000000     121019       121019     121019.000000
# unique        1            NaN       8698           69               NaN
# top         INR            NaN  BENGALURU  MAHARASHTRA               NaN
# freq     121019            NaN      10659        21048               NaN
# mean        NaN     648.631921        NaN          NaN     463515.105306
# std         NaN     281.224583        NaN          NaN     191442.074611
# min         NaN       0.000000        NaN          NaN          0.000000
# 25%         NaN     449.000000        NaN          NaN     382421.000000
# 50%         NaN     605.000000        NaN          NaN     500032.000000
# 75%         NaN     788.000000        NaN          NaN     600020.000000
# max         NaN    5584.000000        NaN          NaN     989898.000000
#
#        ship-country     B2B fulfilled-by
# count        120988  121019       121019
# unique            1       2            2
# top              IN   False       unkown
# freq         120988  120176        83542
# mean            NaN     NaN          NaN
# std             NaN     NaN          NaN
# min             NaN     NaN          NaN
# 25%             NaN     NaN          NaN
# 50%             NaN     NaN          NaN
# 75%             NaN     NaN          NaN
# max             NaN     NaN          NaN

# %%
df.isna().sum()
# Out:
# Order ID               0
# Date                   0
# Status                 0
# Fulfilment             0
# Sales Channel          0
# ship-service-level     0
# Category               0
# Size                   0
# Courier Status         0
# Qty                    0
# currency               0
# Amount                 0
# ship-city              0
# ship-state             0
# ship-postal-code       0
# ship-country          31
# B2B                    0
# fulfilled-by           0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 565

# %%
df["Size"].value_counts()
# Out:
# Size
# M       20948
# L       20461
# XL      19394
# XXL     16767
# S       15630
# 3XL     13870
# XS      10180
# Free     2130
# 6XL       705
# 5XL       526
# 4XL       408
# Name: count, dtype: int64

# %%
sns.histplot(df["Amount"])
# Out:
# <Axes: xlabel='Amount', ylabel='Count'>

# %%
sns.countplot(y="Category", data=df)
# Out:
# <Axes: xlabel='count', ylabel='Category'>

# %%
print(df["Category"].value_counts().head(10))
# Out:
# Category
# T-shirt     46980
# Shirt       46645
# Blazzer     14694
# Trousers    10151
# Perfume      1091
# Wallet        881
# Socks         419
# Shoes         155
# Watch           3
# Name: count, dtype: int64

# %%
print(df["Size"].value_counts().head(10).sort_values(ascending=False))
# Out:
# Size
# M       20948
# L       20461
# XL      19394
# XXL     16767
# S       15630
# 3XL     13870
# XS      10180
# Free     2130
# 6XL       705
# 5XL       526
# Name: count, dtype: int64

# %%
display(df.isna().sum().sort_values(ascending=False))
# Out:
# ship-country          31
# Order ID               0
# Date                   0
# B2B                    0
# ship-postal-code       0
# ship-state             0
# ship-city              0
# Amount                 0
# currency               0
# Qty                    0
# Courier Status         0
# Size                   0
# Category               0
# ship-service-level     0
# Sales Channel          0
# Fulfilment             0
# Status                 0
# fulfilled-by           0
# dtype: int64

# %%
num = df.select_dtypes(include=["number"])
display(num.corr())
# Out:
#                        Qty    Amount  ship-postal-code
# Qty               1.000000  0.066792         -0.005879
# Amount            0.066792  1.000000         -0.038180
# ship-postal-code -0.005879 -0.038180          1.000000

# %%
display(df.groupby("Category")["Amount"].agg(["count","mean","median","sum"]).
        sort_values("count", ascending=False))
# Out:
#           count        mean  median          sum
# Category
# T-shirt   46980  833.421289   788.0  39154132.17
# Shirt     46645  455.992469   435.0  21269768.70
# Blazzer   14694  762.794754   744.0  11208506.12
# Trousers  10151  526.185134   522.0   5341305.30
# Perfume    1091  723.574390   837.0    789419.66
# Wallet      881  520.327106   545.0    458408.18
# Socks       419  358.943914   345.0    150397.50
# Shoes       155  799.572645   791.0    123933.76
# Watch         3  305.000000   305.0       915.00
